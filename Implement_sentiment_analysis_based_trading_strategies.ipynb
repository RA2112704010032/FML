# %%
# !pip install backtrader
# Out:
# Collecting backtrader
#   Downloading backtrader-1.9.78.123-py2.py3-none-any.whl.metadata (6.8 kB)
# Downloading backtrader-1.9.78.123-py2.py3-none-any.whl (419 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 419.5/419.5 kB 7.3 MB/s eta 0:00:00
# Installing collected packages: backtrader
# Successfully installed backtrader-1.9.78.123

# %%
# Import required libraries
import pandas as pd
import numpy as np
import yfinance as yf
from textblob import TextBlob
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import backtrader as bt
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# Download VADER lexicon if not already downloaded
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
# Define the Sentiment indicator class for Backtrader
class Sentiment(bt.Indicator):
    """Custom indicator to track sentiment scores"""
    lines = ('sentiment',)
    plotinfo = dict(
        plotymargin=0.5,
        plothlines=[0],
        plotyticks=[1.0, 0, -1.0]
    )

    def next(self):
        self.sentiment = 0.0
        self.date = self.data.datetime
        date = bt.num2date(self.date[0]).date()
        if date in date_sentiment:
            self.sentiment = date_sentiment[date]
        self.lines.sentiment[0] = self.sentiment

# %%
# Define the trading strategy class
class SentimentStrategy(bt.Strategy):
    """Trading strategy based on sentiment analysis"""
    params = (
        ('period', 15),  # Moving average period
        ('printlog', True),
    )

    def __init__(self):
        # Initialize variables
        self.dataclose = self.datas[0].close
        self.order = None
        self.buyprice = None
        self.buycomm = None

        # Add simple moving average indicator
        self.sma = bt.indicators.SimpleMovingAverage(
            self.datas[0], period=self.params.period)

        # Add sentiment indicator
        self.sentiment = None
        Sentiment(self.data)
        self.plotinfo.plot = False

    def notify_order(self, order):
        """Handle order notifications"""
        if order.status in [order.Submitted, order.Accepted]:
            return

        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(f'BUY EXECUTED, Price: {order.executed.price:.2f}, Cost: {order.executed.value:.2f}, Comm: {order.executed.comm:.2f}')
                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            else:
                self.log(f'SELL EXECUTED, Price: {order.executed.price:.2f}, Cost: {order.executed.value:.2f}, Comm: {order.executed.comm:.2f}')

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')

        self.order = None

    def next(self):
        """Define trading logic"""
        date = bt.num2date(self.data.datetime[0]).date()
        prev_sentiment = self.sentiment

        if date in date_sentiment:
            self.sentiment = date_sentiment[date]

        # Check if we have an open order
        if self.order:
            return

        # Trading logic based on sentiment changes
        if not self.position and prev_sentiment:
            # Buy if price > SMA and sentiment increased significantly
            if self.dataclose[0] > self.sma[0] and self.sentiment - prev_sentiment >= 0.5:
                self.log(f'Previous Sentiment {prev_sentiment:.2f}, New Sentiment {self.sentiment:.2f} BUY CREATE, {self.dataclose[0]:.2f}')
                self.order = self.buy()

        elif prev_sentiment:
            # Sell if price < SMA and sentiment decreased significantly
            if self.dataclose[0] < self.sma[0] and self.sentiment - prev_sentiment <= -0.5:
                self.log(f'Previous Sentiment {prev_sentiment:.2f}, New Sentiment {self.sentiment:.2f} SELL CREATE, {self.dataclose[0]:.2f}')
                self.order = self.sell()

    def log(self, txt, dt=None, doprint=False):
        """Logging function"""
        if self.params.printlog or doprint:
            dt = dt or self.datas[0].datetime.date(0)
            print(f'{dt.isoformat()}, {txt}')

# %%
# Function to run the trading strategy
def run_strategy(ticker, start_date, end_date, initial_cash=100000.0):
    """
    Run the trading strategy for a given ticker

    Parameters:
    ticker (str): Stock ticker symbol
    start_date (str): Start date in 'YYYY-MM-DD' format
    end_date (str): End date in 'YYYY-MM-DD' format
    initial_cash (float): Initial investment amount
    """

    # Create Backtrader engine
    cerebro = bt.Cerebro()

    # Add strategy
    cerebro.addstrategy(SentimentStrategy)

    # Get stock data
    stock = yf.Ticker(ticker)
    df = stock.history(start=start_date, end=end_date)

    # Add data feed
    data = bt.feeds.PandasData(dataname=df)
    cerebro.adddata(data)

    # Set initial cash
    cerebro.broker.setcash(initial_cash)

    # Set position size
    cerebro.addsizer(bt.sizers.FixedSize, stake=100)

    # Print initial portfolio value
    print(f'Starting Portfolio Value: ${initial_cash:.2f}')

    # Run strategy
    cerebro.run()

    # Plot results
    cerebro.plot(volume=False, style='candlestick')

    # Get final portfolio value
    final_value = cerebro.broker.getvalue()
    profit = final_value - initial_cash

    print(f'Final Portfolio Value: ${final_value:.2f}')
    print(f'Profit/Loss: ${profit:.2f}')

    return float(df['Close'][0]), profit

# %%
if __name__ == "__main__":
    # Define trading parameters
    TICKER = 'AAPL'
    START_DATE = '2020-01-01'
    END_DATE = '2023-12-31'
    INITIAL_CASH = 100000.0

    dates = pd.date_range(start=START_DATE, end=END_DATE)
    date_sentiment = {date.date(): np.random.uniform(-1, 1) for date in dates}

    # Run strategy
    initial_price, profit = run_strategy(TICKER, START_DATE, END_DATE, INITIAL_CASH)

    # Print results
    print(f"\nSummary:")
    print(f"Initial {TICKER} price: ${initial_price:.2f}")
    print(f"Total profit/loss: ${profit:.2f}")
    print(f"Return on Investment: {(profit/INITIAL_CASH)*100:.2f}%")
# Out:
# Starting Portfolio Value: $100000.00
# 2020-02-05, Previous Sentiment -0.75, New Sentiment 0.36 BUY CREATE, 78.00
# 2020-02-06, BUY EXECUTED, Price: 78.27, Cost: 7826.75, Comm: 0.00
# 2020-02-21, Previous Sentiment 0.24, New Sentiment -0.86 SELL CREATE, 76.14
# 2020-02-24, SELL EXECUTED, Price: 72.30, Cost: 7826.75, Comm: 0.00
# 2020-03-31, Previous Sentiment -0.99, New Sentiment 0.37 BUY CREATE, 61.85
# 2020-04-01, BUY EXECUTED, Price: 59.95, Cost: 5995.20, Comm: 0.00
# 2020-04-02, Previous Sentiment 0.63, New Sentiment -0.70 SELL CREATE, 59.57
# 2020-04-03, SELL EXECUTED, Price: 59.05, Cost: 5995.20, Comm: 0.00
# 2020-04-08, Previous Sentiment -0.88, New Sentiment 0.16 BUY CREATE, 64.71
# 2020-04-09, BUY EXECUTED, Price: 65.35, Cost: 6535.14, Comm: 0.00
# 2020-07-29, Previous Sentiment 0.84, New Sentiment -0.57 SELL CREATE, 92.71
# 2020-07-30, SELL EXECUTED, Price: 91.88, Cost: 6535.14, Comm: 0.00
# 2020-07-31, Previous Sentiment -0.32, New Sentiment 0.36 BUY CREATE, 103.66
# 2020-08-03, BUY EXECUTED, Price: 105.55, Cost: 10554.76, Comm: 0.00
# 2020-09-03, Previous Sentiment -0.09, New Sentiment -0.80 SELL CREATE, 118.13
# 2020-09-04, SELL EXECUTED, Price: 117.34, Cost: 10554.76, Comm: 0.00
# 2020-09-28, Previous Sentiment -0.81, New Sentiment 0.21 BUY CREATE, 112.34
# 2020-09-29, BUY EXECUTED, Price: 111.94, Cost: 11194.34, Comm: 0.00
# 2020-10-22, Previous Sentiment 0.99, New Sentiment 0.47 SELL CREATE, 113.12
# 2020-10-23, SELL EXECUTED, Price: 113.74, Cost: 11194.34, Comm: 0.00
# 2020-11-06, Previous Sentiment -0.80, New Sentiment 0.02 BUY CREATE, 116.19
# 2020-11-09, BUY EXECUTED, Price: 117.96, Cost: 11796.12, Comm: 0.00
# 2020-11-24, Previous Sentiment 0.90, New Sentiment -0.61 SELL CREATE, 112.74
# 2020-11-25, SELL EXECUTED, Price: 113.12, Cost: 11796.12, Comm: 0.00
# 2020-11-30, Previous Sentiment -0.94, New Sentiment 0.35 BUY CREATE, 116.54
# 2020-12-01, BUY EXECUTED, Price: 118.46, Cost: 11846.04, Comm: 0.00
# 2021-01-04, Previous Sentiment 0.89, New Sentiment 0.30 SELL CREATE, 126.68
# 2021-01-05, SELL EXECUTED, Price: 126.17, Cost: 11846.04, Comm: 0.00
# 2021-01-07, Previous Sentiment -0.60, New Sentiment 0.39 BUY CREATE, 128.16
# 2021-01-08, BUY EXECUTED, Price: 129.64, Cost: 12963.98, Comm: 0.00
# 2021-01-19, Previous Sentiment 0.48, New Sentiment -0.18 SELL CREATE, 125.14
# 2021-01-20, SELL EXECUTED, Price: 125.95, Cost: 12963.98, Comm: 0.00
# 2021-01-20, Previous Sentiment -0.18, New Sentiment 0.36 BUY CREATE, 129.25
# 2021-01-21, BUY EXECUTED, Price: 130.98, Cost: 13098.10, Comm: 0.00
# 2021-02-10, Previous Sentiment 0.63, New Sentiment 0.02 SELL CREATE, 132.74
# 2021-02-11, SELL EXECUTED, Price: 133.24, Cost: 13098.10, Comm: 0.00
# 2021-03-15, Previous Sentiment -0.03, New Sentiment 0.85 BUY CREATE, 121.56
# 2021-03-16, BUY EXECUTED, Price: 123.24, Cost: 12323.55, Comm: 0.00
# 2021-03-19, Previous Sentiment 0.85, New Sentiment 0.02 SELL CREATE, 117.64
# 2021-03-22, SELL EXECUTED, Price: 117.97, Cost: 12323.55, Comm: 0.00
# 2021-03-22, Previous Sentiment 0.02, New Sentiment 0.55 BUY CREATE, 120.97
# 2021-03-23, BUY EXECUTED, Price: 120.91, Cost: 12091.20, Comm: 0.00
# 2021-03-24, Previous Sentiment 0.16, New Sentiment -0.52 SELL CREATE, 117.74
# 2021-03-25, SELL EXECUTED, Price: 117.20, Cost: 12091.20, Comm: 0.00
# 2021-03-31, Previous Sentiment -0.33, New Sentiment 0.31 BUY CREATE, 119.76
# 2021-04-01, BUY EXECUTED, Price: 121.24, Cost: 12123.55, Comm: 0.00
# 2021-04-30, Previous Sentiment 0.81, New Sentiment -0.60 SELL CREATE, 128.88
# 2021-05-03, SELL EXECUTED, Price: 129.45, Cost: 12123.55, Comm: 0.00
# 2021-05-26, Previous Sentiment -0.80, New Sentiment 0.86 BUY CREATE, 124.57
# 2021-05-27, BUY EXECUTED, Price: 124.17, Cost: 12417.15, Comm: 0.00
# 2021-05-27, Previous Sentiment 0.86, New Sentiment 0.07 SELL CREATE, 123.03
# 2021-05-28, SELL EXECUTED, Price: 123.32, Cost: 12417.15, Comm: 0.00
# 2021-06-08, Previous Sentiment -0.74, New Sentiment 0.52 BUY CREATE, 124.47
# 2021-06-09, BUY EXECUTED, Price: 124.93, Cost: 12492.77, Comm: 0.00
# 2021-07-19, Previous Sentiment 0.33, New Sentiment -0.49 SELL CREATE, 139.89
# 2021-07-20, SELL EXECUTED, Price: 140.89, Cost: 12492.77, Comm: 0.00
# 2021-07-20, Previous Sentiment -0.49, New Sentiment 0.15 BUY CREATE, 143.53
# 2021-07-21, BUY EXECUTED, Price: 142.92, Cost: 14291.90, Comm: 0.00
# 2021-07-28, Previous Sentiment 0.46, New Sentiment -0.51 SELL CREATE, 142.38
# 2021-07-29, SELL EXECUTED, Price: 142.09, Cost: 14291.90, Comm: 0.00
# 2021-08-05, Previous Sentiment -0.84, New Sentiment 0.61 BUY CREATE, 144.42
# 2021-08-06, BUY EXECUTED, Price: 143.94, Cost: 14393.97, Comm: 0.00
# 2021-08-19, Previous Sentiment 0.97, New Sentiment -0.42 SELL CREATE, 144.28
# 2021-08-20, SELL EXECUTED, Price: 145.01, Cost: 14393.97, Comm: 0.00
# 2021-08-20, Previous Sentiment -0.42, New Sentiment 0.81 BUY CREATE, 145.75
# 2021-08-23, BUY EXECUTED, Price: 145.87, Cost: 14586.74, Comm: 0.00
# 2021-09-10, Previous Sentiment 0.52, New Sentiment -0.81 SELL CREATE, 146.52
# 2021-09-13, SELL EXECUTED, Price: 148.15, Cost: 14586.74, Comm: 0.00
# 2021-10-15, Previous Sentiment -0.14, New Sentiment 0.56 BUY CREATE, 142.45
# 2021-10-18, BUY EXECUTED, Price: 141.09, Cost: 14108.74, Comm: 0.00
# 2021-11-11, Previous Sentiment 0.34, New Sentiment -0.85 SELL CREATE, 145.65
# 2021-11-12, SELL EXECUTED, Price: 146.20, Cost: 14108.74, Comm: 0.00
# 2021-11-15, Previous Sentiment -0.57, New Sentiment 1.00 BUY CREATE, 147.74
# 2021-11-16, BUY EXECUTED, Price: 147.69, Cost: 14768.58, Comm: 0.00
# 2021-12-20, Previous Sentiment 0.18, New Sentiment -0.84 SELL CREATE, 167.20
# 2021-12-21, SELL EXECUTED, Price: 168.98, Cost: 14768.58, Comm: 0.00
# 2021-12-21, Previous Sentiment -0.84, New Sentiment -0.29 BUY CREATE, 170.39
# 2021-12-22, BUY EXECUTED, Price: 170.44, Cost: 17043.84, Comm: 0.00
# 2022-01-05, Previous Sentiment 0.89, New Sentiment -0.23 SELL CREATE, 172.29
# 2022-01-06, SELL EXECUTED, Price: 170.10, Cost: 17043.84, Comm: 0.00
# 2022-01-31, Previous Sentiment -0.95, New Sentiment 0.43 BUY CREATE, 172.15
# 2022-02-01, BUY EXECUTED, Price: 171.39, Cost: 17139.39, Comm: 0.00
# 2022-02-11, Previous Sentiment 0.75, New Sentiment -0.49 SELL CREATE, 166.32
# 2022-02-14, SELL EXECUTED, Price: 165.06, Cost: 17139.39, Comm: 0.00
# 2022-02-16, Previous Sentiment -0.41, New Sentiment 0.21 BUY CREATE, 170.17
# 2022-02-17, BUY EXECUTED, Price: 168.67, Cost: 16867.33, Comm: 0.00
# 2022-02-17, Previous Sentiment 0.21, New Sentiment -0.69 SELL CREATE, 166.55
# 2022-02-18, SELL EXECUTED, Price: 167.48, Cost: 16867.33, Comm: 0.00
# 2022-03-18, Previous Sentiment -0.61, New Sentiment 0.89 BUY CREATE, 161.72
# 2022-03-21, BUY EXECUTED, Price: 161.26, Cost: 16125.69, Comm: 0.00
# 2022-04-07, Previous Sentiment 0.34, New Sentiment -0.67 SELL CREATE, 169.77
# 2022-04-08, SELL EXECUTED, Price: 169.41, Cost: 16125.69, Comm: 0.00
# 2022-05-04, Previous Sentiment -0.66, New Sentiment 0.71 BUY CREATE, 163.73
# 2022-05-05, BUY EXECUTED, Price: 161.59, Cost: 16159.23, Comm: 0.00
# 2022-05-06, Previous Sentiment 0.65, New Sentiment -0.44 SELL CREATE, 155.34
# 2022-05-09, SELL EXECUTED, Price: 153.02, Cost: 16159.23, Comm: 0.00
# 2022-06-01, Previous Sentiment -0.99, New Sentiment 0.52 BUY CREATE, 146.88
# 2022-06-02, BUY EXECUTED, Price: 146.01, Cost: 14600.72, Comm: 0.00
# 2022-06-16, Previous Sentiment 0.70, New Sentiment -0.12 SELL CREATE, 128.46
# 2022-06-17, SELL EXECUTED, Price: 128.47, Cost: 14600.72, Comm: 0.00
# 2022-07-05, Previous Sentiment -0.84, New Sentiment 0.84 BUY CREATE, 139.81
# 2022-07-06, BUY EXECUTED, Price: 139.61, Cost: 13960.71, Comm: 0.00
# 2022-08-23, Previous Sentiment 0.40, New Sentiment -0.35 SELL CREATE, 165.40
# 2022-08-24, SELL EXECUTED, Price: 165.49, Cost: 13960.71, Comm: 0.00
# 2022-10-18, Previous Sentiment 0.13, New Sentiment 0.74 BUY CREATE, 142.17
# 2022-10-19, BUY EXECUTED, Price: 140.14, Cost: 14013.73, Comm: 0.00
# 2022-11-07, Previous Sentiment -0.04, New Sentiment -0.69 SELL CREATE, 137.63
# 2022-11-08, SELL EXECUTED, Price: 139.10, Cost: 14013.73, Comm: 0.00
# 2022-11-11, Previous Sentiment -0.70, New Sentiment -0.12 BUY CREATE, 148.31
# 2022-11-14, BUY EXECUTED, Price: 147.58, Cost: 14758.19, Comm: 0.00
# 2022-11-28, Previous Sentiment 0.85, New Sentiment 0.06 SELL CREATE, 142.88
# 2022-11-29, SELL EXECUTED, Price: 142.95, Cost: 14758.19, Comm: 0.00
# 2023-01-11, Previous Sentiment -0.01, New Sentiment 0.98 BUY CREATE, 132.25
# 2023-01-12, BUY EXECUTED, Price: 132.63, Cost: 13263.26, Comm: 0.00
# 2023-02-22, Previous Sentiment 0.38, New Sentiment -0.91 SELL CREATE, 147.75
# 2023-02-23, SELL EXECUTED, Price: 148.92, Cost: 13263.26, Comm: 0.00
# 2023-03-03, Previous Sentiment -0.99, New Sentiment 0.63 BUY CREATE, 149.85
# 2023-03-06, BUY EXECUTED, Price: 152.59, Cost: 15258.96, Comm: 0.00
# 2023-05-04, Previous Sentiment 0.95, New Sentiment -0.13 SELL CREATE, 164.50
# 2023-05-05, SELL EXECUTED, Price: 169.65, Cost: 15258.96, Comm: 0.00
# 2023-05-11, Previous Sentiment -0.66, New Sentiment 0.72 BUY CREATE, 172.39
# 2023-05-12, BUY EXECUTED, Price: 172.50, Cost: 17250.31, Comm: 0.00
# 2023-05-24, Previous Sentiment 0.53, New Sentiment -0.21 SELL CREATE, 170.73
# 2023-05-25, SELL EXECUTED, Price: 171.30, Cost: 17250.31, Comm: 0.00
# 2023-05-26, Previous Sentiment -0.86, New Sentiment 0.24 BUY CREATE, 174.30
# 2023-05-30, BUY EXECUTED, Price: 175.82, Cost: 17582.17, Comm: 0.00
# 2023-08-03, Previous Sentiment 0.27, New Sentiment -0.87 SELL CREATE, 189.94
# 2023-08-04, SELL EXECUTED, Price: 184.33, Cost: 17582.17, Comm: 0.00
# 2023-08-25, Previous Sentiment 0.39, New Sentiment 0.96 BUY CREATE, 177.70
# 2023-08-28, BUY EXECUTED, Price: 179.17, Cost: 17917.31, Comm: 0.00
# 2023-09-12, Previous Sentiment 0.43, New Sentiment -0.23 SELL CREATE, 175.40
# 2023-09-13, SELL EXECUTED, Price: 175.61, Cost: 17917.31, Comm: 0.00
# 2023-10-06, Previous Sentiment -0.71, New Sentiment -0.15 BUY CREATE, 176.59
# 2023-10-09, BUY EXECUTED, Price: 175.91, Cost: 17590.98, Comm: 0.00
# 2023-10-23, Previous Sentiment 0.66, New Sentiment 0.15 SELL CREATE, 172.12
# 2023-10-24, SELL EXECUTED, Price: 172.17, Cost: 17590.98, Comm: 0.00
# 2023-11-02, Previous Sentiment -0.42, New Sentiment 0.90 BUY CREATE, 176.67
# 2023-11-03, BUY EXECUTED, Price: 173.35, Cost: 17335.30, Comm: 0.00
# 2023-12-26, Previous Sentiment 0.68, New Sentiment -0.27 SELL CREATE, 192.32
# 2023-12-27, SELL EXECUTED, Price: 191.76, Cost: 17335.30, Comm: 0.00
# <div id='a9a0fec0-7dce-4000-b683-8bc409cd4172'></div>
# Final Portfolio Value: $112409.50
# Profit/Loss: $12409.50
#
# Summary:
# Initial AAPL price: $72.88
# Total profit/loss: $12409.50
# Return on Investment: 12.41%
